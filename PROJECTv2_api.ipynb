# %%
# !pip install replicate

# %%
# get a token: https://replicate.com/account
from getpass import getpass
import os

REPLICATE_API_TOKEN = getpass()
os.environ["REPLICATE_API_TOKEN"] = REPLICATE_API_TOKEN
# Out:
# ··········

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-562abcf5-4ea4-46b9-a5e3-f54cdb3ef079" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-562abcf5-4ea4-46b9-a5e3-f54cdb3ef079">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import subprocess

command = "ffmpeg -i /content/video.mp4 -ab 160k -ac 2 -ar 44100 -vn /content/extractaud.wav"

subprocess.call(command, shell=True)
# Out:
# 0

# %%
# !pip install git+https://github.com/openai/whisper.git
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-egn0252w
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-egn0252w
#   Resolved https://github.com/openai/whisper.git to commit b91c907694f96a3fb9da03d4bbdc83fbcd3a40a4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 11.4 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20230314-py3-none-any.whl size=798283 sha256=65eed60a52298f98d2f02441cb3c330dc8aa25d422527a7181ff883eaca3fba8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2algh4y9/wheels/8b/6c/d0/622666868c179f156cf595c8b6f06f88bc5d80c4b31dccaa03
# Successfully built openai-whisper
# ...

# %%
import whisper

model = whisper.load_model("small")
result = model.transcribe(audio="/content/extractaud.wav", language="Hindi", task="translate")
print(result["text"])
text = result["text"]
# Out:
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:114: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  Everything will be fine in the end.

# %%
import replicate
output1 = replicate.run(
    "afiaka87/tortoise-tts:e9658de4b325863c4fcdc12d94bb7c9b54cbfe351b7ca1b36860008172b91c71",
    input={"text": text ,"voice_a": "custom_voice","custom_voice": "https://huggingface.co/datasets/MadLaDEV404/test/resolve/main/untitled.mp3"}
)
print(output1)
# Out:
# https://replicate.delivery/pbxt/GeHRxBtihfiAq0izARjr52iyfEBrjQdQDo2WZsAegpfIAYyKC/tortoise.mp3

# %%
# !wget $output1
# Out:
# --2023-08-03 08:18:53--  https://replicate.delivery/pbxt/IXf03fLB3tklgkEl7UykUlQtskcCGUK66yIJTjPS08eeNFZFB/tortoise.mp3
# Resolving replicate.delivery (replicate.delivery)... 104.26.12.87, 104.26.13.87, 172.67.71.67, ...
# Connecting to replicate.delivery (replicate.delivery)|104.26.12.87|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://pbxt.replicate.delivery/IXf03fLB3tklgkEl7UykUlQtskcCGUK66yIJTjPS08eeNFZFB/tortoise.mp3 [following]
# --2023-08-03 08:18:53--  https://pbxt.replicate.delivery/IXf03fLB3tklgkEl7UykUlQtskcCGUK66yIJTjPS08eeNFZFB/tortoise.mp3
# Resolving pbxt.replicate.delivery (pbxt.replicate.delivery)... 34.110.130.253, 2600:1901:0:ee3b::
# Connecting to pbxt.replicate.delivery (pbxt.replicate.delivery)|34.110.130.253|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9165 (9.0K) [audio/mpeg]
# Saving to: ‘tortoise.mp3’
#
# ...

# %%
from IPython.display import Audio, display

display(Audio('/content/tortoise.mp3', autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import replicate
output = replicate.run(
    "devxpy/cog-wav2lip:8d65e3f4f4298520e079198b493c25adfc43c058ffec924f2aefc8010ed25eef",
    input={"face": open("/content/video.mp4", "rb") ,"audio":open("/content/tortoise.mp3", "rb")}
)
print(output)
# Out:
# https://pbxt.replicate.delivery/58fvQLPdXJXqSyHO4efJ96tiOfzi7pfgd4jXfbMOoRb8GWkVE/result_voice.mp4

# %%
# !wget $output
# Out:
# --2023-08-03 08:24:39--  https://pbxt.replicate.delivery/58fvQLPdXJXqSyHO4efJ96tiOfzi7pfgd4jXfbMOoRb8GWkVE/result_voice.mp4
# Resolving pbxt.replicate.delivery (pbxt.replicate.delivery)... 34.110.130.253, 2600:1901:0:ee3b::
# Connecting to pbxt.replicate.delivery (pbxt.replicate.delivery)|34.110.130.253|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 634105 (619K) [video/mp4]
# Saving to: ‘result_voice.mp4’
#
# result_voice.mp4    100%[===================>] 619.24K  --.-KB/s    in 0.009s
#
# 2023-08-03 08:24:39 (69.4 MB/s) - ‘result_voice.mp4’ saved [634105/634105]

# %%
from IPython.display import Video

Video("/content/result_voice.mp4" ,embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
